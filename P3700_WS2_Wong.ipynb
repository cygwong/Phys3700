# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.arange(0,9)
plt.axis([0,8,0,8])
plt.xlabel("Analog Sample Value")
plt.ylabel("Quantized Level")
plt.plot(x)
plt.step(x,x-1)
plt.show()

x=np.arange(0,9)
plt.axis([0,7,-1,1])
plt.xlabel("Analog Sample Value")
plt.ylabel("Quantized Error")
# value change
actual = np.arange[0,7,0.01]
i = 0
while i < 8:
    qerr = 0
    
plt.plot(x)
plt.step(x,x-1)
plt.show()
